# %% [markdown]
# <a href="https://colab.research.google.com/github/brongar71/curso-DNC/blob/main/Fernando_Brongar_da_Fontoura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/sample_data/Walmart.csv')

# %%
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df.Holiday_Flag.value_counts(0)
# Out:
# 0    5985
# 1     450
# Name: Holiday_Flag, dtype: int64

# %%
df_feriado = df[df.Holiday_Flag == 1]

# %%
df_feriado.head()
# Out:
#     Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1       1  12-02-2010    1641957.44             1        38.51       2.548
# 31      1  10-09-2010    1507460.69             1        78.69       2.565
# 42      1  26-11-2010    1955624.11             1        64.52       2.735
# 47      1  31-12-2010    1367320.01             1        48.43       2.943
# 53      1  11-02-2011    1649614.93             1        36.39       3.022
#
#            CPI  Unemployment
# 1   211.242170         8.106
# 31  211.495190         7.787
# 42  211.748433         7.838
# 47  211.404932         7.838
# 53  212.936705         7.742

# %%
soma_vendas = df_feriado.Weekly_Sales.sum()

# %%
soma_vendas
# Out:
# 505299551.56

# %%
df_dn = df[df.Holiday_Flag == 0]
df_dn.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
# 5      1  12-03-2010    1439541.59             0        57.79       2.667
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106
# 5  211.380643         8.106

# %%
soma_vendas = df_dn.Weekly_Sales.sum()
soma_vendas
# Out:
# 6231919435.55

# %%
df_dn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5985 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         5985 non-null   int64
#  1   Date          5985 non-null   object
#  2   Weekly_Sales  5985 non-null   float64
#  3   Holiday_Flag  5985 non-null   int64
#  4   Temperature   5985 non-null   float64
#  5   Fuel_Price    5985 non-null   float64
#  6   CPI           5985 non-null   float64
#  7   Unemployment  5985 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 420.8+ KB

# %%
df.Date = pd.to_datetime(df['Date'],  format='%d-%m-%Y') 
df.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-02-05    1643690.90             0        42.31       2.572
# 1      1 2010-02-12    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-03-05    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 402.3 KB

# %%
df['mes'] = df.Date.dt.month
df.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-02-05    1643690.90             0        42.31       2.572
# 1      1 2010-02-12    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-03-05    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment  mes
# 0  211.096358         8.106    2
# 1  211.242170         8.106    2
# 2  211.289143         8.106    2
# 3  211.319643         8.106    2
# 4  211.350143         8.106    3

# %%
plt.figure(figsize = (15,8))
sns.scatterplot(data=df, x=df.mes, y=df.Weekly_Sales, hue = df.Holiday_Flag)
